# %% [markdown]
# # 네이버 검색 API 서비스

# %% [markdown]
# ## 네이버 웹문서 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "0g_YNhKCfMhiuIXoL05R"
client_secret = "QmxRe8MJ1Y"

query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display = 100
start = 1
end = 1000

web_df = pd.DataFrame(columns=('Title', 'Link', 'Description'))

for start_index in range(start, end, display):

  url = "https://openapi.naver.com/v1/search/webkr?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index) # json 결과

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title'])
        link = items[item_index]['link']
        description = re.sub(remove_tag, '', items[item_index]['description'])
        web_df.loc[idx] = [title, link, description]
        idx += 1
  else:
      print("Error Code:" + rescode)

web_df
# Out:
# 검색 질의: 한삼열
#                                                 Title  ...                                        Description
# 0                        재학생 - 서울대학교 대학원 협동과정 환경교육 전공  ...  Martin 생태체험교육 개발 평가 한삼열 2020 /박사과정 이은주 [석사수료] ...
# 1           커뮤니티 &gt; 중보기도 1 페이지 - 전북CBS에 오신것을 환영합니다.  ...  위해서 ^^ 한삼열 2015-07-17 1759 42 A 형 다혈질 인 선미 를 위...
# 2                     10 ㎞ 남·여 완주자 : 부산의 대표 정론지, 국제신문  ...  한민용 한삼열 한종우 한종철 한창길 한창훈 한치근 한홍재 허남기 허무정 허상기 허성...
# 3            평화뉴스 모바일 사이트, 대선 1년, 대구 '부정선거ㆍ정권심판' 시국선언  ...  홈 정치/경제 국정원 대선개입·NLL 논란 대선 1년, 대구 '부정선거ㆍ정권심판' ...
# 4            [배너광고] 성주·김천 주민 여러분 힘내세요 - 평화군축센터 - 참여연대  ...  평화군축센터 한반도 평화를 위해 비핵군축운동을 합니다 [배너광고] 성주·김천 주민 ...
# 5               중고 . S-F600 . 1 조 . &gt; 질문답변 | 사가코리아  ...  문자나 으로 연락주십시오한삼열님 예약되었습니다 . 네트워크 조립하여 장착하여드리겠습...
# 6                                     영농회 - [NH 청송농협]  ...  이현 한삼열 김인자 김영조 중기1 김희구 송정숙 김주환 중기2 이상관 김순희 이상관...
# 7        관권부정선거 규탄, 박근혜 정권 심판 1219대구시국선언 - 정의당 대구광역시당  ...  [ 관권부정선거 규탄, 박근혜 정권 심판 1219대구시국선언 ] 대한민국은 민주 공...
# 8           커뮤니티 &gt; 중보기도 1 페이지 - 전북CBS에 오신것을 환영합니다.  ...  위해서 ^^ 한삼열 2015-07-17 1741 42 A 형 다혈질 인 선미 를 위...
# 9       중고 . asw-20 . 8&quot; X 2 . &gt; 질문답변 | 사가코리아  ...  ^^운영자 작성일 04-12-14 00:00 한삼열님 예약 되었습니다 ....한삼열...
# 10                   나의 신앙유산답사기 (목포편4), 유진벨의 사역 :기독공보  ...  나의 신앙유산답사기 (목포편4), 유진벨의 사역 편집인 | 입력 : 2020/09/...
# 11           국가보안법 폐지 농민선언 (2004, 11, 4) - 전국여성농민회총연합  ...  전여농 성명서 ㆍ 작성자 전여농 ㆍ 작성일 2004-11-05 (금) 12:43 ㆍ...
# 12                         이장회의 서류(140408).hwp - 청송군청  ...  31 ○ 신청방법 : 농작업대행단 전화 신청 ∙ 한삼열 : ***-****-****...
# 13                  景敎의 성립과 唐 전래 - 상세정보 | 연세대학교 학술정보원  ...  학위논문景敎의 성립과 唐 전래 / 한삼열 한삼열 서울 : 연세대학교 교육대학원, 2...
# 14  밭기반정비사업(전환)(전환사업) - 산소카페 청송군-명품사과의 고장, 청송 &gt;...  ...  통합검색 세부사업명 밭기반정비사업(전환)(전환사업) 회계년도 2021 회계 일반회계...
# 15    벼육묘공장지원 - 산소카페 청송군-명품사과의 고장, 청송 &gt; 지출내역(통계목별)  ...  통합검색 세부사업명 벼육묘공장지원 회계년도 2021 회계 일반회계 조직 농정과 기능...
# 16                                       대구광역시 북구의회소식  ...  고성동 한삼열 의원 송창주 의원 칠성동 다선거구(산격1·2·3·4·디현동) 안경완 ...
# 17         [당첨자발표] BBN 카본 클리닝 무료체험 - 『 BK mania.com 』  ...  THERED(한삼열) IP : 1.***.155.240 | 2016-07-03 20...
# 18                                  향유 담은 옥합 - 다음 블로그  ...  스바냐 제 1장 =======1;1 아몬의 아들 유다 왕 요시야의 시대 - 선지자 ...
# 19                                         CBS On Air  ...                                    CBS, 설교, 간증, 찬송
# 20                                         CBS On Air  ...                                    CBS, 설교, 간증, 찬송
# 21                         이장회의(2016.9.13).hwp - 청송군청  ...  30(72일간) ❍ 포획지역 : 관내 농경지주변 전역 ❍ 해당방지단 : 부동․부남․...
# 22                                         CBS On Air  ...                                    CBS, 설교, 간증, 찬송
# 23                 [신문광고] 사드 가고 평화 오라 - 평화군축센터 - 참여연대  ...  평화군축센터 한반도 평화를 위해 비핵군축운동을 합니다 [신문광고] 사드 가고 평화 ...
# 24     농토배양사업 - 산소카페 청송군-명품사과의 고장, 청송 &gt; 지출내역(통계목별)  ...  통합검색 세부사업명 농토배양사업 회계년도 2021 회계 일반회계 조직 농정과 기능 ...
# 25       [신문광고] 한국 어디에도 사드 배치 최적지는 없다 - 평화군축센터 - 참여연대  ...  평화군축센터 한반도 평화를 위해 비핵군축운동을 합니다 [신문광고] 한국 어디에도 사...
# 26                        이장회의(2017.03.24).hwp - 청송군청  ...  - 인근 벼 육묘공장 ∙ 부남 벼육묘공장(한삼열) ∙ 부남 소형육묘공장(고두종) ∙...
# 27  [당첨자발표] BBN 카본 클리닝 무료체험 - 『 BK mania.com 』 :: ...  ...  THERED(한삼열) (2016-07-03 20:52:05) 댓글양식 : 지역 : ...
# 28                        이장회의(2019.12.11).hwp - 청송군청  ...  17 청송군 부남면 대전로 113-6 여 야생생물 ***-****-**** 9 한삼...
# 29                            미국 남 장로교의 호남 선교 역사 여행 ④  ...  【20190804-0106】 미국 남南 장로교의 호남 선교 역사 여행 ④ -Davi...
# 30  찬양찬양이있는곳에 &gt; 청취자세상 &gt; 하나님 나라 에 영광 을 위하여 ( ...  ...  하나님 익산 병원 에서 힘들게 어렙게 일 하고 있는 하나님 의 귀하고 귀한 딸 장선...
# 31  찬양찬양이있는곳에 &gt; 생방송문자참여 1 페이지 - 전북CBS에 오신것을 환영합니다.  ...  Home &gt; 찬양찬양이있는곳에 &gt; 생방송문자참여 번호 제목 이름 등록일 ...
# 32                         한삼열님의 녹색교통선진문화 실천다짐의 글입니다.  ...  녹색교통선진문화 실천다짐의 글 교통안전을 통해 도민의 귀중한 생명과 재산을 보호하고...
# 33                     자동차부품 쇼핑몰 TENDOWN에 오신 것을 환영합니다  ...  부품문의/주문서 (건)[1] 한삼열2013-06-19 08:27:50 어퍼콘솔/11...
# 34                             학교여 일어나라! 노은고 한삼열 학생과!  ...  제 목 : 학교여 일어나라! 노은고 한삼열 학생과! 2014-10-07 오전 8:2...
# 35                         이장회의(2016.9.23).hwp - 청송군청  ...  30(72일간) ❍ 포획지역 : 관내 농경지주변 전역 ❍ 해당방지단 : 부동․부남․...
# 36     농토배양사업 - 산소카페 청송군-명품사과의 고장, 청송 &gt; 지출내역(통계목별)  ...  통합검색 검색열기 검색닫기 검색방법 선택검색방법 열기 통합검색담당직원검색 통합검색통...
# 37                           景敎의 성립과 唐 전래 | 언더우드기념도서관  ...  학위논문景敎의 성립과 唐 전래 / 한삼열 한삼열 서울 : 연세대학교 교육대학원, 2...
# 38  커뮤니티 &gt; 중보기도 &gt; 쉬지말고 기도 하라 선미 를 위해서 ^^ - 전...  ...  전북표준FM / 음악FM / TV TV 라디오 뉴스 전북노컷 E-크리스천 방송발전기...
# 39      한일장신대학교 &gt; 커뮤니티 &gt; 신학부 학부생들의 호칭, 이대로 좋은가?  ...  총장실 이사회 연혁 및 역사 교육이념 규정.요람.발전계획 대학조직 정보공개 한일 상...
# 40                  이장회의 서류(2020.11.13)_최종.hwp - 청송군청  ...  24일 한삼열씨 댁 앞 45 이현세절고추창고 46 화장리 이재철씨 댁 앞 15 화장...
# 41  커뮤니티 &gt; 중보기도 &gt; 개인적인 기도의 제목 을 하나님 앞에 올려 놓습...  ...  전북표준FM / 음악FM / TV TV 라디오 뉴스 전북노컷 E-크리스천 방송발전기...
# 42  국가보안법_폐지_농민선언_기자회견_자료.hwp - 전농 - 투쟁하는 전농! 승리하는...  ...  국가보안법 폐지 1000인 농민선언 기자회견 □ 일시 : 2004년 11월 4일 1...
# 43                                  향유 담은 옥합 - 다음 블로그  ...  이 땅의 것을 버리고 포기해야 한다. 이래도 그만 저래도 그만인 것들이기 때문이다....
# 44          북한과학기술 우리나라 中小企業의 對 北韓 進出에 관한 연구 - K2Base  ...  북한과학기술 정책 라이브러리 ⁄ 과학기술정책자료 ⁄ 북한과학기술 제목 우리나라 中小...
# 45                                      ENG - 한일장신대학교  ...  한일E-CAMPUS 한일E-CAMPUS 한일광장 캠퍼스갤러리 캠퍼스갤러리 글쓴이 :...
# 46                 2009년 제2회 수렵면허 합격자 공고문.hwp - 경상북도청  ...  100078 한삼열 100081 정병호 100082 김성하 100085 권태신 10...
# 47                             청송 `청정미나리` 첫 출하 - 대구일보  ...  이날 부남면 이현리 한삼열(35)씨 밭에서 배대윤 군수와 이상열 농협지부장 등 30...
# 48                           You have to admit to win  ...  SBS Running Man 구독 조회수 2 668 535 98% 30 000 59...
# 49            영월 연이굴 유적의 동물화석 연구 - 상세정보 | 연세대학교 학술정보원  ...  영월 연이굴 유적의 동물화석 연구 이창원 자료유형 학위논문 서명/저자사항 영월 연이...
# 50  어린이박물관의 교육내용 분석 : 국립제주박물관을 중심으로 - 상세정보 | 연세대학교...  ...  어린이박물관의 교육내용 분석 : 국립제주박물관을 중심으로 오혜진 자료유형 학위논문 ...
# 51  Democratic movement in Thailand : comparing th...  ...  Democratic movement in Thailand : comparing th...
# 52                                 5월 30일 학생리더 버스킹전도!  ...  지난 토요일 버스킹은 노은고 기도모임 친구들과 함께 했어요 ~ 한삼열, 이재용 두 ...
# 53           공민왕대 초반 반원적 개혁정치 연구 - 상세정보 | 연세대학교 학술정보원  ...  공민왕대 초반 반원적 개혁정치 연구 김지영 자료유형 학위논문 서명/저자사항 공민왕대...
# 54  [Ep.9]학창시절 짝사랑했던 남사친의 뒤늦은 고백 &quot;나 너 많이 좋아했었...  ...  여자친구랑 여사친 다 갖고노는거야 한삼열8 개월 전 저는 인연 우연 이 있다면 우연...
# 55        어린이박물관의 교육내용 분석 : 국립제주박물관을 중심으로 | 언더우드기념도서관  ...  자료유형 학위논문 서명/저자사항 어린이박물관의 교육내용 분석 : 국립제주박물관을 중...
# 56  Democratic movement in Thailand : comparing th...  ...  Democratic movement in Thailand : comparing th...
# 57                    공민왕대 초반 반원적 개혁정치 연구 | 언더우드기념도서관  ...  자료유형 학위논문 서명/저자사항 공민왕대 초반 반원적 개혁정치 연구 / 김지영 개인...
# 58                     영월 연이굴 유적의 동물화석 연구 | 언더우드기념도서관  ...  자료유형 학위논문 서명/저자사항 영월 연이굴 유적의 동물화석 연구 / 이창원 개인저...
# 59      쿠팡 품절대란 다이어트식품 리얼볼륨포뮬러 판매해용 - 취향을 잇는 거래, 번개장터  ...  쿠팡 품절대란 다이어트식품 리얼볼륨포뮬러 판매해용 4,000원 3 187 11달 전...
#
# [60 rows x 3 columns]

# %% [markdown]
# ## 네이버 지식iN 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "0g_YNhKCfMhiuIXoL05R"
client_secret = "QmxRe8MJ1Y"

query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display = 100
start = 1
end = 1000
sort = "sim"

kin_df = pd.DataFrame(columns=('Title', 'Link', 'Description'))

for start_index in range(start, end, display):

  url = "https://openapi.naver.com/v1/search/kin?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index) \
        + "&sort=" + sort # json 결과

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title'])
        link = items[item_index]['link']
        description = re.sub(remove_tag, '', items[item_index]['description'])
        kin_df.loc[idx] = [title, link, description]
        idx += 1
  else:
      print("Error Code:" + rescode)

kin_df
# Out:
# 검색 질의: 컴퓨터
#                Title  ...                                        Description
# 0       컴퓨터학원 답해주세요!  ...  컴퓨터학원 알아보고 있는데요. 일을 쉬는중이라 컴퓨터학원 다니면서 추 후에 일을 할...
# 1             컴퓨터 부품  ...  안녕하세요 컴퓨터에대해 아는 지식이 하나도 없는데ㅠ 데스크탑 컴퓨터랑 조립식 컴퓨터...
# 2    컴퓨터공학 졸업장이 급합니다  ...  ... 학점은행제로 컴퓨터공학 졸업장을따면 된다고 하고 저는 4년제 졸업을해서 또 ...
# 3       컴퓨터가 저절로 켜져요  ...  컴퓨터를 종료를 계속 해도 지멋대로 켜지고있는데 막 내컴퓨터 속성들어가서 재부팅되는...
# 4        컴퓨터학원 묻습니다.  ...  컴퓨터학원 좋은데 알수있을까요? 찾아보니깐 컴퓨터학원 많이 나와서 딱 컴퓨터 배울곳...
# ..               ...  ...                                                ...
# 995        컴퓨터 기초..책  ...  이제 대학교 컴퓨터학과에 입학할학생입니다! 컴퓨터학과들어가기전에 컴퓨터에대해 아는게...
# 996     컴퓨터 쓸수있는 핑계!  ...  제가 컴퓨터를 쓰고 싶은데 저희 집이 컴퓨터 쓰는걸 별로 안 좋아해서 거의... 어...
# 997        게임 컴퓨터 질문  ...  게임 컴퓨터 살려고 하는데 제가 컴퓨터에 대해서 1도 모르거든요? 게임은 피파4 ,...
# 998   컴퓨터 고장나서 수리맡길때  ...  컴퓨터가 요즘 자꾸 그냥 인터냇볼때도 계속 다운되는게 반복되서 컴퓨터 수리점에 맡길...
# 999      조립컴퓨터 견적 문의  ...  조립컴퓨터를 맞추려고하는데요. 조립컴퓨터를 어떻게 맞춰야 할지 모르겟어요. 조립컴퓨...
#
# [1000 rows x 3 columns]

# %% [markdown]
# ## 네이버 블로그 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "0g_YNhKCfMhiuIXoL05R"
client_secret = "QmxRe8MJ1Y"

query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display = 100
start = 1
end = 1000
sort = "sim"

blog_df = pd.DataFrame(columns=('Title', 'Link', 'Description', 'Blogger Name', 'Blogger Link', 'Post Date'))

for start_index in range(start, end, display):

  url = "https://openapi.naver.com/v1/search/blog?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index) \
        + "&sort=" + sort # json 결과

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title'])
        link = items[item_index]['link']
        description = re.sub(remove_tag, '', items[item_index]['description'])
        blogger_name = items[item_index]['bloggername']
        blogger_link = items[item_index]['bloggerlink']
        post_date = items[item_index]['postdate']
        blog_df.loc[idx] = [title, link, description, blogger_name, blogger_link, post_date]
        idx += 1
  else:
      print("Error Code:" + rescode)

blog_df
# Out:
# 검색 질의: 컴퓨터
#                                               Title  ... Post Date
# 0                                    컴퓨터학원 선택 아닌 필수  ...  20210923
# 1                          컴퓨터활용능력1급 혼자 공부하기 위한 접근법  ...  20210918
# 2                                  컴퓨터학원 취업까지 일사천리!  ...  20210923
# 3                                컴퓨터학원 실력 향상 교육 절차!  ...  20210924
# 4                              부산 컴퓨터 수리 밥 줄을 지켜주세요  ...  20210923
# ..                                              ...  ...       ...
# 995                        한성컴퓨터 올데이롱 TFX5470H 구매후기  ...  20210220
# 996             [공감리뷰] 가성비 1인용컴퓨터책상 제닉스 아레나 데스크...   ...  20210727
# 997                   컴퓨터 인간 / Deadly Friend(1986년)  ...  20210724
# 998                           컴퓨터를 보는 시간을 되도록 줄이려~~  ...  20210728
# 999  [해운대 좌동 컴퓨터 조립] AMD Ryzen9 5950X + MSI RTX...   ...  20210712
#
# [1000 rows x 6 columns]

# %% [markdown]
# ## 네이버 책 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "0g_YNhKCfMhiuIXoL05R"
client_secret = "QmxRe8MJ1Y"

query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display = 100
start = 1
end = 1000
sort = "sim"

book_df = pd.DataFrame(columns=('Title', 'Link', 'Image', 'Author', 'Price', 'Discount', 'Publisher', 'ISBN', 'Description', 'Publication Date'))

for start_index in range(start, end, display):

  url = "https://openapi.naver.com/v1/search/book?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index) \
        + "&sort=" + sort # json 결과

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title'])
        link = items[item_index]['link']
        image = items[item_index]['image']
        author = items[item_index]['author']
        price = items[item_index]['price']
        discount = items[item_index]['discount']
        publisher = items[item_index]['publisher']
        isbn = items[item_index]['isbn']
        description = re.sub(remove_tag, '', items[item_index]['description'])
        pubdate = items[item_index]['pubdate']
        book_df.loc[idx] = [title, link, image, author, price, discount, publisher, isbn, description, pubdate]
        idx += 1
  else:
      print("Error Code:" + rescode)

book_df
# Out:
# 검색 질의: 컴퓨터
#                                                  Title  ... Publication Date
# 0    2021 시나공 컴퓨터활용능력 2급 실기 (컴활 함수 사전 + 자동 채점 프로그램 ...  ...         20201026
# 1    컴퓨터활용능력 1급 필기(2021)(시나공) (필수암기집+동영상강의+암기프로그램+기...  ...         20200923
# 2    2021 시나공 컴퓨터활용능력 1급 실기 (컴활함수사전 + 자동 채점 프로그램 + ...  ...         20201026
# 3    컴퓨터활용능력 2급 필기(2021)(시나공) (필수암기집+동영상강의+암기프로그램+기...  ...         20200923
# 4    2022 시나공 총정리 컴퓨터활용능력 1급 필기 (8절) (핵심요약 + 기출문제 +...  ...         20210802
# ..                                                 ...  ...              ...
# 995                  이기적 in 컴퓨터활용능력 2급 실기 기출문제집 (2014)  ...         20131122
# 996                                       인간과 컴퓨터의 어울림  ...         20140415
# 997                       백발백중 컴퓨터그래픽스 운용기능사 실기 (2011)  ...         20100901
# 998  우체국 9급 계리직 공무원 컴퓨터 일반 (2016, (2008~2014) 전4회 기...  ...         20150610
# 999             송광진 정보컴퓨터 적중문제풀이 2 (2019 중등교원 임용시험 대비)  ...         20180804
#
# [1000 rows x 10 columns]

# %% [markdown]
# ## 네이버 영화 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "0g_YNhKCfMhiuIXoL05R"
client_secret = "QmxRe8MJ1Y"

query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display = 100
start = 1
end = 1000
sort = "sim"

movie_df = pd.DataFrame(columns=('Title', 'Link', 'Image', 'Subtitle', 'Publication Date', 'Director', 'Actor', 'user Rating'))

for start_index in range(start, end, display):

  url = "https://openapi.naver.com/v1/search/movie?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index) \
        + "&sort=" + sort # json 결과

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title'])
        link = items[item_index]['link']
        image = items[item_index]['image']
        subtitle = items[item_index]['subtitle']
        pub_date = items[item_index]['pubDate']
        director = items[item_index]['director']
        actor = items[item_index]['actor']
        user_rating = items[item_index]['userRating']
        movie_df.loc[idx] = [title, link, image, subtitle, pub_date, director, actor, user_rating]
        idx += 1
  else:
      print("Error Code:" + rescode)

movie_df
# Out:
# 검색 질의: 아이언맨
#                    Title  ... user Rating
# 0        일론 머스크: 리얼 아이언맨  ...        5.32
# 1                   아이언맨  ...        4.95
# 2     아이언맨 &amp; 캡틴 아메리카  ...        9.00
# 3                 아이언맨 3  ...        8.86
# 4    아이언 맨: 라이즈 오브 테크노보어  ...        3.09
# ..                   ...  ...         ...
# 125           인빈서블 아이언 맨  ...        7.24
# 126     특수공작원 아이언맨 - 시리즈  ...        7.63
# 127           특수공작원 아이언맨  ...        9.00
# 128                아이언 맨  ...        5.37
# 129                아이언 맨  ...        7.54
#
# [130 rows x 8 columns]

# %% [markdown]
# ## 네이버 쇼핑 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "0g_YNhKCfMhiuIXoL05R"
client_secret = "QmxRe8MJ1Y"

query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display = 100
start = 1
end = 1000
sort = "sim"

shop_df = pd.DataFrame(columns=('Title', 'Link', 'Image', 'Low Price', 'High Price', 'Mall Name', 'Product ID', 'Product Type', 'Maker', 'Brand'))

for start_index in range(start, end, display):

  url = "https://openapi.naver.com/v1/search/shop?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index) \
        + "&sort=" + sort # json 결과

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title'])
        link = items[item_index]['link']
        image = items[item_index]['image']
        low_price = items[item_index]['lprice']
        high_price = items[item_index]['hprice']
        mall_name = items[item_index]['mallName']
        product_id = items[item_index]['productId']
        product_type = items[item_index]['productType']
        maker = items[item_index]['maker']
        brand = items[item_index]['brand']
        shop_df.loc[idx] = [title, link, image, low_price, high_price, mall_name, product_id, product_type, maker, brand]
        idx += 1
  else:
      print("Error Code:" + rescode)

shop_df
# Out:
# 검색 질의: 컴퓨터
#                                                  Title  ...  Brand
# 0                    아싸컴 프리미엄 게이밍 i5-9400F + 외장형 그래픽카드  ...    아싸컴
# 1     프리미엄 게이밍 조립컴퓨터 RTX3070 배틀그라운드 오버워치 롤 배그 컴퓨터본체 견적  ...   마루PC
# 2                            프리플로우 GAMING CREATOR 356S  ...  프리플로우
# 3                                    LG전자 27V70N-FR50K  ...   LG전자
# 4                                       디클 올인원 PC A238  ...     디클
# ..                                                 ...  ...    ...
# 995                        기가바이트 GB-BLCE-4105 M.2 제이씨현  ...
# 996                               삼성전자 삼성 DM301S3B-C20  ...     삼성
# 997             에스다/라이젠3200G/4350G/4650G/240GB/8G/조립PC  ...
# 998  LG 24V50N-GR56K 24인치 재택근무 가정용 업무용 주식 일체형 컴퓨터 올...  ...   LG전자
# 999                              삼성전자 삼성 DM500T7A-A34S  ...     삼성
#
# [1000 rows x 10 columns]

# %% [markdown]
# ## 네이버 뉴스 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "0g_YNhKCfMhiuIXoL05R"
client_secret = "QmxRe8MJ1Y"

query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display = 100
start = 1
end = 1000
sort = "sim"

news_df = pd.DataFrame(columns=('Title', 'Original Link', 'Link', 'Description', 'Publication Date'))

for start_index in range(start, end, display):

  url = "https://openapi.naver.com/v1/search/news?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index) \
        + "&sort=" + sort # json 결과

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title'])
        original_link = items[item_index]['originallink']
        link = items[item_index]['link']
        description = re.sub(remove_tag, '', items[item_index]['description'])
        pub_date = items[item_index]['pubDate']
        news_df.loc[idx] = [title, original_link, link, description, pub_date]
        idx += 1
  else:
      print("Error Code:" + rescode)

news_df
# Out:
# 검색 질의: 컴퓨터
#                                                  Title  ...                 Publication Date
# 0        검찰, 컴퓨터·서류 등 2박스 확보…성남도시개발공사 압수수색 10시간 만에 ...  ...  Wed, 29 Sep 2021 19:50:00 +0900
# 1                      시각장애인용 태블릿 컴퓨터 등…신기술과 신제품 눈에 띄네  ...  Wed, 29 Sep 2021 11:01:00 +0900
# 2              이화여대, 컴퓨터공학전공 창립 40주년 맞아...국내 컴공과 최장 역사  ...  Wed, 29 Sep 2021 13:59:00 +0900
# 3                              이화여대 컴퓨터공학전공 창립 40주년 맞아  ...  Wed, 29 Sep 2021 10:56:00 +0900
# 4                             이화여대, 컴퓨터공학전공 창립 40주년 맞아  ...  Wed, 29 Sep 2021 10:35:00 +0900
# ..                                                 ...  ...                              ...
# 995                    “한글과컴퓨터, 글로벌 클라우드 SaaS기업으로 대전환”  ...  Tue, 10 Aug 2021 15:48:00 +0900
# 996                     컴투스, '승리호' 컴퓨터그래픽 만든 위지윅 최대주주로  ...  Wed, 25 Aug 2021 09:56:00 +0900
# 997                       기상청 슈퍼컴퓨터 설치 완료, 10월 기상예측 투입  ...  Tue, 10 Aug 2021 07:46:00 +0900
# 998      한글과컴퓨터 목표주가 상향, &quot;클라우드사업으로 기업가치 재평가&quot;  ...  Tue, 10 Aug 2021 09:44:00 +0900
# 999  [하이&amp;로우] &quot;한글과컴퓨터, 클라우드 기업으로 대전환&quot; ...  ...  Tue, 10 Aug 2021 09:44:00 +0900
#
# [1000 rows x 5 columns]
