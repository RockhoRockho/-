# %% [markdown]
# # 한국환경공단 대기오염정보

# %% [markdown]
# ## 한국환경공단_측정소정보
#
# * https://www.data.go.kr/tcs/dss/selectApiDataDetailView.do?publicDataPk=15073877

# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
from xml.etree import ElementTree
import pandas as pd

skey ='R0Wnbv0TpQW2w3AH8ezK89SSX3e1rFBgUq4lhFuA3oek1BOSEFlSvQSJ0mxXQ7NK+q5rNWSy7VJKU0VQykvEUg=='

url = 'http://apis.data.go.kr/B552584/MsrstnInfoInqireSvc/getNearbyMsrstnList'
params = '?' + \
urlencode({quote_plus('serviceKey') : skey,
           quote_plus('returnType') : 'xml',
           quote_plus('tmX') : '244148.546388',
           quote_plus('tmY') : '412423.75772',
           quote_plus('ver') : '1.0' })
print(url + params)

request = Request(url + params)
request.get_method = lambda: 'GET'
response_body = urlopen(request).read()
#print(response_body)

root = ElementTree.fromstring(response_body)

df = pd.DataFrame()
for item in root.iter('item'):
    item_dict = {}
    item_dict['tm'] = item.find('tm').text
    item_dict['addr'] = item.find('addr').text
    item_dict['stationName'] = item.find('stationName').text
    df = df.append(item_dict, ignore_index=True)
    
df
# Out:
# http://apis.data.go.kr/B552584/MsrstnInfoInqireSvc/getNearbyMsrstnList?serviceKey=R0Wnbv0TpQW2w3AH8ezK89SSX3e1rFBgUq4lhFuA3oek1BOSEFlSvQSJ0mxXQ7NK%2Bq5rNWSy7VJKU0VQykvEUg%3D%3D&returnType=xml&tmX=244148.546388&tmY=412423.75772&ver=1.0
#                                        addr stationName      tm
# 0  제주특별자치도 서귀포시 대정읍 동일하모로149번길 21-8대정청소년수련관         대정읍  1236.7
# 1                        제주 제주시 한경면 고산리3762         고산리  1238.7
# 2           제주 서귀포시 동홍동 453-1(서귀포소방서)서귀포소방서         동홍동  1253.9

# %% [markdown]
# ## 한국환경공단_에어코리아_대기오염정보
#
# * https://www.data.go.kr/tcs/dss/selectApiDataDetailView.do?publicDataPk=15073861

# %% [markdown]
# ### 측정소별 실시간 측정정보 조회

# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
from xml.etree import ElementTree
import pandas as pd

skey ='R0Wnbv0TpQW2w3AH8ezK89SSX3e1rFBgUq4lhFuA3oek1BOSEFlSvQSJ0mxXQ7NK+q5rNWSy7VJKU0VQykvEUg=='

url = 'http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getMsrstnAcctoRltmMesureDnsty'
params = '?' + \
urlencode({quote_plus('serviceKey') : skey,
           quote_plus('returnType') : 'xml',
           quote_plus('numOfRows') : '100',
           quote_plus('pageNo') : '1',
           quote_plus('stationName') : '종로구',
           quote_plus('dataTerm') : 'DAILY',
           quote_plus('ver') : '1.0' })
print(url + params)

request = Request(url + params)
request.get_method = lambda: 'GET'
response_body = urlopen(request).read()
#print(response_body)

root = ElementTree.fromstring(response_body)

df = pd.DataFrame()
for item in root.iter('item'):
    item_dict = {}
    item_dict['so2Grade'] = item.find('so2Grade').text
    item_dict['coFlag'] = item.find('coFlag').text
    item_dict['khaiValue'] = item.find('khaiValue').text
    item_dict['so2Value'] = item.find('so2Value').text
    item_dict['coValue'] = item.find('coValue').text
    item_dict['pm25Flag'] = item.find('pm25Flag').text
    item_dict['pm10Flag'] = item.find('pm10Flag').text
    item_dict['pm10Value'] = item.find('pm10Value').text
    item_dict['o3Grade'] = item.find('o3Grade').text
    item_dict['khaiGrade'] = item.find('khaiGrade').text
    item_dict['pm25Value'] = item.find('pm25Value').text
    item_dict['no2Flag'] = item.find('no2Flag').text
    item_dict['no2Grade'] = item.find('no2Grade').text
    item_dict['o3Flag'] = item.find('o3Flag').text
    item_dict['pm25Grade'] = item.find('pm25Grade').text
    item_dict['so2Flag'] = item.find('so2Flag').text
    item_dict['dataTime'] = item.find('dataTime').text
    item_dict['coGrade'] = item.find('coGrade').text
    item_dict['no2Value'] = item.find('no2Value').text
    item_dict['pm10Grade'] = item.find('pm10Grade').text
    item_dict['o3Value'] = item.find('o3Value').text
    
    df = df.append(item_dict, ignore_index=True)
    
df
# Out:
# http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getMsrstnAcctoRltmMesureDnsty?serviceKey=R0Wnbv0TpQW2w3AH8ezK89SSX3e1rFBgUq4lhFuA3oek1BOSEFlSvQSJ0mxXQ7NK%2Bq5rNWSy7VJKU0VQykvEUg%3D%3D&returnType=xml&numOfRows=100&pageNo=1&stationName=%EC%A2%85%EB%A1%9C%EA%B5%AC&dataTerm=DAILY&ver=1.0
#    coFlag coGrade coValue          dataTime khaiGrade khaiValue no2Flag  \
# 0    None       1     0.7  2021-10-02 23:00         2        69    None
# 1    None       1     0.7  2021-10-02 22:00         2        66    None
# 2    None       1     0.7  2021-10-02 21:00         2        64    None
# 3    None       1     0.6  2021-10-02 20:00         2        63    None
# 4    None       1     0.5  2021-10-02 19:00         2        73    None
# 5    None       1     0.5  2021-10-02 18:00         2        76    None
# 6    None       1     0.4  2021-10-02 17:00         2        84    None
# 7    None       1     0.4  2021-10-02 16:00         2        83    None
# 8    None       1     0.4  2021-10-02 15:00         2        83    None
# 9    None       1     0.4  2021-10-02 14:00         2        74    None
# 10   None       1     0.4  2021-10-02 13:00         2        68    None
# 11   None       1     0.4  2021-10-02 12:00         2        60    None
# 12   None       1     0.4  2021-10-02 11:00         2        53    None
# 13   None       1     0.5  2021-10-02 10:00         1        47    None
# 14   None       1     0.4  2021-10-02 09:00         1        47    None
# 15   None       1     0.4  2021-10-02 08:00         1        50    None
# 16   None       1     0.4  2021-10-02 07:00         1        38    None
# 17   None       1     0.4  2021-10-02 06:00         1        42    None
# 18   None       1     0.4  2021-10-02 05:00         1        48    None
# 19   None       1     0.4  2021-10-02 04:00         1        48    None
# 20   None       1     0.3  2021-10-02 03:00         2        58    None
# 21   None       1     0.3  2021-10-02 02:00         2        59    None
# 22   None       1     0.3  2021-10-02 01:00         2        63    None
#
#    no2Grade no2Value o3Flag  ... o3Value pm10Flag pm10Grade pm10Value  \
# 0         2    0.037   None  ...   0.019     None         2        41
# 1         2    0.038   None  ...   0.022     None         2        43
# 2         2    0.033   None  ...   0.036     None         2        46
# 3         1    0.030   None  ...   0.046     None         2        40
# 4         1    0.027   None  ...   0.057     None         1        38
# 5         1    0.020   None  ...   0.061     None         1        32
# 6         1    0.015   None  ...   0.071     None         1        31
# 7         1    0.014   None  ...   0.070     None         1        28
# 8         1    0.016   None  ...   0.069     None         1        31
# 9         1    0.019   None  ...   0.059     None         1        34
# 10        1    0.019   None  ...   0.051     None         1        30
# 11        1    0.022   None  ...   0.042     None         1        26
# 12        1    0.025   None  ...   0.033     None         1        24
# 13        1    0.028   None  ...   0.020     None         1        18
# 14        1    0.028   None  ...   0.015     None         1        15
# 15        1    0.030   None  ...   0.012     None         1        14
# 16        1    0.022   None  ...   0.023     None         1        13
# 17        1    0.019   None  ...   0.025     None         1        11
# 18        1    0.016   None  ...   0.029     None         1        11
# 19        1    0.016   None  ...   0.029     None         1        10
# 20        1    0.015   None  ...   0.039     None         1         9
# 21        1    0.014   None  ...   0.041     None         1         9
# 22        1    0.012   None  ...   0.046     None         2        10
#
#    pm25Flag pm25Grade pm25Value so2Flag so2Grade so2Value
# 0      None         2        25    None        1    0.003
# 1      None         2        27    None        1    0.004
# 2      None         2        30    None        1    0.003
# 3      None         2        25    None        1    0.004
# 4      None         2        25    None        1    0.004
# 5      None         2        19    None        1    0.003
# 6      None         1        19    None        1    0.004
# 7      None         1        14    None        1    0.003
# 8      None         1        21    None        1    0.003
# 9      None         1        20    None        1    0.003
# 10     None         1        16    None        1    0.003
# 11     None         1        13    None        1    0.003
# 12     None         1        11    None        1    0.003
# 13     None         1         7    None        1    0.003
# 14     None         1         7    None        1    0.003
# 15     None         1         7    None        1    0.003
# 16     None         1         7    None        1    0.003
# 17     None         1         7    None        1    0.003
# 18     None         1         9    None        1    0.002
# 19     None         1         7    None        1    0.003
# 20     None         1         8    None        1    0.003
# 21     None         2         6    None        1    0.003
# 22     None         2         7    None        1    0.002
#
# [23 rows x 21 columns]

# %% [markdown]
# ## 시도별 실시간 측정정보 조회

# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
from xml.etree import ElementTree
import pandas as pd

skey ='R0Wnbv0TpQW2w3AH8ezK89SSX3e1rFBgUq4lhFuA3oek1BOSEFlSvQSJ0mxXQ7NK+q5rNWSy7VJKU0VQykvEUg=='

url = 'http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty'
params = '?' + \
urlencode({quote_plus('serviceKey') : skey,
           quote_plus('returnType') : 'xml',
           quote_plus('numOfRows') : '100',
           quote_plus('pageNo') : '1',
           quote_plus('sidoName') : '서울',
           quote_plus('ver') : '1.0' })
print(url + params)

request = Request(url + params)
request.get_method = lambda: 'GET'
response_body = urlopen(request).read()
#print(response_body)

root = ElementTree.fromstring(response_body)

df = pd.DataFrame()
for item in root.iter('item'):
    item_dict = {} 
    item_dict['so2Grade'] = item.find('so2Grade').text
    item_dict['coFlag'] = item.find('coFlag').text
    item_dict['khaiValue'] = item.find('khaiValue').text
    item_dict['so2Value'] = item.find('so2Value').text
    item_dict['coValue'] = item.find('coValue').text
    item_dict['pm25Flag'] = item.find('pm25Flag').text
    item_dict['pm10Flag'] = item.find('pm10Flag').text
    item_dict['pm10Value'] = item.find('pm10Value').text
    item_dict['o3Grade'] = item.find('o3Grade').text
    item_dict['khaiGrade'] = item.find('khaiGrade').text
    item_dict['pm25Value'] = item.find('pm25Value').text
    item_dict['no2Flag'] = item.find('no2Flag').text
    item_dict['no2Grade'] = item.find('no2Grade').text
    item_dict['o3Flag'] = item.find('o3Flag').text
    item_dict['pm25Grade'] = item.find('pm25Grade').text
    item_dict['so2Flag'] = item.find('so2Flag').text
    item_dict['dataTime'] = item.find('dataTime').text
    item_dict['coGrade'] = item.find('coGrade').text
    item_dict['no2Value'] = item.find('no2Value').text
    item_dict['stationName'] = item.find('stationName').text
    item_dict['pm10Grade'] = item.find('pm10Grade').text
    item_dict['o3Value'] = item.find('o3Value').text
    
    df = df.append(item_dict, ignore_index=True)
    
df
# Out:
# http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty?serviceKey=R0Wnbv0TpQW2w3AH8ezK89SSX3e1rFBgUq4lhFuA3oek1BOSEFlSvQSJ0mxXQ7NK%2Bq5rNWSy7VJKU0VQykvEUg%3D%3D&returnType=xml&numOfRows=100&pageNo=1&sidoName=%EC%84%9C%EC%9A%B8&ver=1.0
#    coFlag coGrade coValue          dataTime khaiGrade khaiValue no2Flag  \
# 0    None       1     0.8  2021-10-02 23:00         2        57    None
# 1    None       1     0.7  2021-10-02 23:00         2        64    None
# 2    None       1     0.6  2021-10-02 23:00         2        53    None
# 3    None       1     0.5  2021-10-02 23:00         2        63    None
# 4    None       1     0.7  2021-10-02 23:00         2        69    None
# 5    None       1     0.5  2021-10-02 23:00         2        64    None
# 6    None       1     0.5  2021-10-02 23:00         2        58    None
# 7    None       1     0.5  2021-10-02 23:00         2        63    None
# 8    None       1     0.5  2021-10-02 23:00         2        66    None
# 9    None       1     0.6  2021-10-02 23:00         2        66    None
# 10   None       1     0.5  2021-10-02 23:00         2        66    None
# 11   None       1     0.7  2021-10-02 23:00         2        72    None
# 12   None       1     0.5  2021-10-02 23:00         2        69    None
# 13   None       1     0.5  2021-10-02 23:00         2        66    None
# 14   None       1     0.5  2021-10-02 23:00         2        66    None
# 15   None       1     0.8  2021-10-02 23:00         2        69    None
# 16   None       1     0.8  2021-10-02 23:00         2        78    None
# 17   None       1     0.6  2021-10-02 23:00         2        69    None
# 18   None       1     0.7  2021-10-02 23:00         2        75    None
# 19   None       1     0.7  2021-10-02 23:00         2        90    None
# 20   None       1     0.5  2021-10-02 23:00         2        66    None
# 21   None       1     0.7  2021-10-02 23:00         2        92    None
# 22   None       1     0.5  2021-10-02 23:00         2        66    None
# 23   None       1     0.5  2021-10-02 23:00         2        69    None
# 24   None       1     0.6  2021-10-02 23:00         2        69    None
# 25   None       1     0.8  2021-10-02 23:00         2        73    None
# 26   None       1     0.6  2021-10-02 23:00         2        86    None
# 27   None       1     0.8  2021-10-02 23:00         2        70    None
# 28   None       1     0.7  2021-10-02 23:00         2        69    None
# 29   None       1     0.8  2021-10-02 23:00         2        85    None
# 30   None       1     0.6  2021-10-02 23:00         2        59    None
# 31   None       1     0.5  2021-10-02 23:00         2        66    None
# 32   None       1     0.7  2021-10-02 23:00         2        69    None
# 33   None       1     0.5  2021-10-02 23:00         2        68    None
# 34   None       1     0.6  2021-10-02 23:00         2        70    None
# 35   None       1     0.5  2021-10-02 23:00         2        59    None
# 36   None       1     0.6  2021-10-02 23:00         2        66    None
# 37   None       1     0.6  2021-10-02 23:00         2        74    None
# 38   None       1     1.0  2021-10-02 23:00         2        90    None
# 39   None       1     0.7  2021-10-02 23:00         2        93    None
#
#    no2Grade no2Value o3Flag  ... pm10Flag pm10Grade pm10Value pm25Flag  \
# 0         2    0.034   None  ...     None         2        41     None
# 1         1    0.022   None  ...     None         2        33     None
# 2         1    0.019   None  ...     None         2        31     None
# 3         1    0.024   None  ...     None         2        40     None
# 4         2    0.040   None  ...     None         2        43     None
# 5         1    0.027   None  ...     None         2        40     None
# 6         1    0.024   None  ...     None         2        35     None
# 7         1    0.017   None  ...     None         2        33     None
# 8         1    0.021   None  ...     None         2        38     None
# 9         2    0.040   None  ...     None         2        42     None
# 10        1    0.024   None  ...     None         2        42     None
# 11        2    0.042   None  ...     None         2        45     None
# 12        1    0.023   None  ...     None         2        42     None
# 13        1    0.028   None  ...     None         2        39     None
# 14        1    0.025   None  ...     None         2        35     None
# 15        1    0.027   None  ...     None         2        43     None
# 16        2    0.047   None  ...     None         2        37     None
# 17        2    0.039   None  ...     None         2        44     None
# 18        2    0.045   None  ...     None         2        44     None
# 19        2    0.054   None  ...     None         2        52     None
# 20        2    0.031   None  ...     None         2        39     None
# 21        2    0.055   None  ...     None         2        50     None
# 22        1    0.013   None  ...     None         2        44     None
# 23        1    0.026   None  ...     None         2        43     None
# 24        2    0.033   None  ...     None         2        42     None
# 25        2    0.044   None  ...     None         2        43     None
# 26        2    0.052   None  ...     None         2        43     None
# 27        2    0.042   None  ...     None         2        59     None
# 28        2    0.037   None  ...     None         2        41     None
# 29        2    0.051   None  ...     None         2        47     None
# 30        1    0.029   None  ...     None         2        34     None
# 31        1    0.022   None  ...     None         2        36     None
# 32        2    0.031   None  ...     장비점검         2         -     None
# 33        2    0.041   None  ...     None         2        48     None
# 34        2    0.042   None  ...     None         2        41     None
# 35        1    0.026   None  ...     None         2        44     None
# 36        2    0.034   None  ...     None         2        44     None
# 37        2    0.042   None  ...     None         2        45     None
# 38        2    0.054   None  ...     None         2        44     None
# 39        2    0.056   None  ...     None         2        42     None
#
#    pm25Grade pm25Value so2Flag so2Grade so2Value stationName
# 0          2        20    자료이상     None        -         도봉구
# 1          2        24    None        1    0.003         은평구
# 2          1        14    None        1    0.003        서대문구
# 3          2        20    None        1    0.004         마포구
# 4          2        24    None        1    0.005         신촌로
# 5          2        21    None        1    0.004         강서구
# 6          2        18    None        1    0.003        공항대로
# 7          2        19    None        1    0.003         구로구
# 8          2        24    None        1    0.004        영등포구
# 9          2        24    None        1    0.004        영등포로
# 10         2        23    None        1    0.003         동작구
# 11         2        26    None        1    0.003   동작대로 중앙차로
# 12         2        25    None        1    0.004         관악구
# 13         2        23    None        1    0.004         강남구
# 14         2        21    None        1    0.004         서초구
# 15         2        25    None        1    0.004        도산대로
# 16         2        17    None        1    0.003        강남대로
# 17         2        30    None        1    0.003         송파구
# 18         2        26    None        1    0.002         강동구
# 19         2        29    None        1    0.003        천호대로
# 20         2        21    None        1    0.003         금천구
# 21         2        24    None        1    0.004        시흥대로
# 22         2        26    None        1    0.002         강북구
# 23         2        26    None        1    0.005         양천구
# 24         2        25    None        1    0.002         노원구
# 25         2        21    None        1    0.004         화랑로
# 26         2        22    None        1    0.004          중구
# 27         2        26    None        1    0.004        한강대로
# 28         2        25    None        1    0.003         종로구
# 29         2        23    None        1    0.004        청계천로
# 30         2        18    None        1    0.003          종로
# 31         2        27    None        1    0.003         용산구
# 32         2        30    None        1    0.002         광진구
# 33         2        24    None        1    0.003         성동구
# 34         2        29    None        1    0.003        강변북로
# 35         2        24    None        1    0.003         중랑구
# 36         2        24    None        1    0.004        동대문구
# 37         2        29    None        1    0.003         홍릉로
# 38         2        20    None        1    0.003         성북구
# 39         2        24    None        1    0.002         정릉로
#
# [40 rows x 22 columns]
